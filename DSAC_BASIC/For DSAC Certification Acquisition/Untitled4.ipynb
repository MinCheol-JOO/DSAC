# %%
for i in range(1,6):
    for k in range(5-i):
        print(" ", end="")
    for j in range(i*2-1):
        print("*", end="")
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
Ist=[]
while True:
    num=int(input("정수입력: "))
    if num ==0:
        break
    lst.append(num)
